# %%
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8856\2572804490.py in ?()
#       9 print(data.head())
#      10
#      11 # Preprocess data (example: scaling)
#      12 scaler = StandardScaler()
# ---> 13 data_scaled = scaler.fit_transform(data)
#      14
#      15 # Define and train SOM
#      16 som = MiniSom(10, 10, data_scaled.shape[1], sigma=1.0, learning_rate=0.5)  # 10x10 grid
#
# ...
